# %%
# !pip install osmnx
import pandas as pd
import geopandas as gpd
import osmnx as ox
import folium
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Collecting osmnx
#   Downloading osmnx-1.2.1-py2.py3-none-any.whl (92 kB)
#      |████████████████████████████████| 92 kB 409 kB/s eta 0:00:01
# Collecting numpy>=1.21
#   Downloading numpy-1.23.0-cp39-cp39-macosx_10_9_x86_64.whl (18.1 MB)
#      |████████████████████████████████| 18.1 MB 195 kB/s eta 0:00:01
# Collecting matplotlib>=3.5
#   Downloading matplotlib-3.5.2-cp39-cp39-macosx_10_9_x86_64.whl (7.3 MB)
#      |████████████████████████████████| 7.3 MB 6.3 MB/s eta 0:00:01
# Requirement already satisfied: Shapely<2.0,>=1.8 in /opt/anaconda3/lib/python3.9/site-packages (from osmnx) (1.8.2)
# Collecting Rtree>=1.0
#   Downloading Rtree-1.0.0-cp39-cp39-macosx_10_9_x86_64.whl (814 kB)
#      |████████████████████████████████| 814 kB 4.1 MB/s eta 0:00:01
# Requirement already satisfied: geopandas>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from osmnx) (0.11.0)
# Requirement already satisfied: pyproj>=3.3 in /opt/anaconda3/lib/python3.9/site-packages (from osmnx) (3.3.1)
# Collecting networkx>=2.8
#   Downloading networkx-2.8.4-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 6.3 MB/s eta 0:00:01
# Collecting requests>=2.27
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 252 kB/s eta 0:00:01
# Collecting pandas>=1.4
#   Downloading pandas-1.4.3-cp39-cp39-macosx_10_9_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 4.4 MB/s eta 0:00:01
# Requirement already satisfied: fiona>=1.8 in /opt/anaconda3/lib/python3.9/site-packages (from geopandas>=0.10->osmnx) (1.8.21)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.9/site-packages (from geopandas>=0.10->osmnx) (21.0)
# Requirement already satisfied: click-plugins>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (1.1.1)
# Requirement already satisfied: munch in /opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (0.7.2)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (2021.10.8)
# Requirement already satisfied: attrs>=17 in /opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (21.2.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (58.0.4)
# Requirement already satisfied: six>=1.7 in /opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (1.16.0)
# Requirement already satisfied: click>=4.0 in /opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.10->osmnx) (8.0.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5->osmnx) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5->osmnx) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5->osmnx) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5->osmnx) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5->osmnx) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5->osmnx) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.4->osmnx) (2021.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27->osmnx) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27->osmnx) (1.26.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27->osmnx) (2.0.4)
# Installing collected packages: numpy, pandas, Rtree, requests, networkx, matplotlib, osmnx
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4
#   Attempting uninstall: Rtree
#     Found existing installation: Rtree 0.9.7
#     Uninstalling Rtree-0.9.7:
#       Successfully uninstalled Rtree-0.9.7
#   Attempting uninstall: requests
#     Found existing installation: requests 2.26.0
#     Uninstalling requests-2.26.0:
#       Successfully uninstalled requests-2.26.0
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.6.3
#     Uninstalling networkx-2.6.3:
#       Successfully uninstalled networkx-2.6.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.4.3
#     Uninstalling matplotlib-3.4.3:
#       Successfully uninstalled matplotlib-3.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.23.0 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.23.0 which is incompatible.
# numba 0.54.1 requires numpy<1.21,>=1.17, but you have numpy 1.23.0 which is incompatible.
# Successfully installed Rtree-1.0.0 matplotlib-3.5.2 networkx-2.8.4 numpy-1.23.0 osmnx-1.2.1 pandas-1.4.3 requests-2.28.1
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/sf/g046x5yd1jddc_829kzg2f840000gn/T/ipykernel_36774/600385400.py in <module>
#       3 import geopandas as gpd
#       4 import osmnx as ox
# ----> 5 import folium
#       6 import matplotlib.pyplot as plt
#       7 import seaborn as sns
#
# ModuleNotFoundError: No module named 'folium'

# %%
place = "Hong Kong, China"
graph = ox.graph_from_place(place, network_type="drive")
len(graph)
# Out:
# 2993

# %%
#Streets
nodes, streets = ox.graph_to_gdfs(graph)
streets.head()
# Out:
#                              osmid  oneway lanes                      name  \
# u        v          key
# 24533064 1618530627 0    743072632    True     2        莊士敦道 Johnston Road
#          297187423  0    567856161   False     2        莊士敦道 Johnston Road
# 26411640 3698862626 0     26560287    True     1     海洋公園道 Ocean Park Road
#          26411641   0     46766846    True     3  黃竹坑道 Wong Chuk Hang Road
# 26411641 597665412  0     86289334    True     4  黃竹坑道 Wong Chuk Hang Road
#
#                                 highway reversed   length  \
# u        v          key
# 24533064 1618530627 0          tertiary    False   38.526
#          297187423  0          tertiary    False   30.191
# 26411640 3698862626 0    secondary_link    False  130.623
#          26411641   0             trunk    False  115.535
# 26411641 597665412  0             trunk    False   81.002
#
#                                                                   geometry  \
# u        v          key
# 24533064 1618530627 0    LINESTRING (114.17317 22.27653, 114.17280 22.2...
#          297187423  0    LINESTRING (114.17317 22.27653, 114.17332 22.2...
# 26411640 3698862626 0    LINESTRING (114.16996 22.25034, 114.17012 22.2...
#          26411641   0    LINESTRING (114.16996 22.25034, 114.17013 22.2...
# 26411641 597665412  0    LINESTRING (114.17105 22.25056, 114.17121 22.2...
#
#                          ref maxspeed bridge area junction access tunnel width
# u        v          key
# 24533064 1618530627 0    NaN      NaN    NaN  NaN      NaN    NaN    NaN   NaN
#          297187423  0    NaN      NaN    NaN  NaN      NaN    NaN    NaN   NaN
# 26411640 3698862626 0    NaN      NaN    NaN  NaN      NaN    NaN    NaN   NaN
#          26411641   0      1      NaN    NaN  NaN      NaN    NaN    NaN   NaN
# 26411641 597665412  0      1      NaN    NaN  NaN      NaN    NaN    NaN   NaN
